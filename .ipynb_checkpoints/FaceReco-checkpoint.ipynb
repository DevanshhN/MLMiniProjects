# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
frame = cv2.imread("IRON-2008-d7a2706.jpg")

# %%
plt.imshow(frame)

# %%
rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)

# %%
cv2.CascadeCla
# Out:
# Init signature: cv2.CascadeClassifier(self, /, *args, **kwargs)
# Docstring:      <no docstring>
# File:           ~/anaconda3/lib/python3.8/site-packages/cv2/cv2.cpython-38-x86_64-linux-gnu.so
# Type:           type
# Subclasses:
