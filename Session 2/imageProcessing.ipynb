# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as ply

import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-b8469e32af05> in <module>
#       3 import matplotlib.pyplot as ply
#       4
# ----> 5 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img = Image.open("IRON-2008-d7a2706.jpg")

# %%
arr = np.array(img)

# %%
ply.imshow(img)

# %%
arr
# Out:
# array([[[198, 227, 231],
#         [197, 226, 230],
#         [195, 226, 229],
#         ...,
#         [220, 238, 240],
#         [218, 236, 238],
#         [217, 235, 237]],
#
#        [[199, 228, 232],
#         [198, 227, 231],
#         [195, 226, 229],
#         ...,
#         [220, 238, 240],
#         [218, 236, 238],
#         [218, 236, 238]],
#
#        [[199, 228, 232],
#         [198, 227, 231],
#         [196, 227, 230],
#         ...,
#         [220, 238, 240],
#         [219, 237, 239],
#         [219, 237, 239]],
#
#        ...,
#
#        [[ 98, 114, 113],
#         [ 97, 113, 112],
#         [ 97, 113, 112],
#         ...,
#         [ 51,  98, 114],
#         [ 45,  92, 108],
#         [ 40,  87, 103]],
#
#        [[ 98, 114, 113],
#         [ 97, 113, 112],
#         [ 97, 113, 112],
#         ...,
#         [ 46,  93, 109],
#         [ 39,  86, 102],
#         [ 34,  81,  97]],
#
#        [[ 98, 114, 113],
#         [ 98, 114, 113],
#         [ 98, 114, 113],
# ...
